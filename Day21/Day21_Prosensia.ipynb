# %%
def add_product(inventory):

    product_name = input("Enter product name: ").strip()
    product_id = input("Enter product ID: ").strip()
    quantity = int(input("Enter product quantity: ").strip())
    price = float(input("Enter product price: ").strip())

    product = {
        "name": product_name,
        "id": product_id,
        "quantity": quantity,
        "price": price
    }
    inventory.append(product)
    print(f"Product {product_name} added successfully.\n")


def view_inventory(inventory):

    if not inventory:
        print("No products in the inventory.\n")
        return

    print("Current Inventory:")
    for product in inventory:
        print(f"Name: {product['name']}, ID: {product['id']}, "
              f"Quantity: {product['quantity']}, Price: {product['price']:.2f}")
    print()


def update_product_quantity(inventory):

    product_id = input("Enter the product ID to update: ").strip()
    for product in inventory:
        if product["id"] == product_id:
            new_quantity = int(input("Enter the new quantity: ").strip())
            product["quantity"] = new_quantity
            print(f"Quantity of product {product['name']} updated successfully.\n")
            return
    print("Product ID not found.\n")


def remove_product(inventory):

    product_id = input("Enter the product ID to remove: ").strip()
    for product in inventory:
        if product["id"] == product_id:
            inventory.remove(product)
            print(f"Product {product['name']} removed successfully.\n")
            return
    print("Product ID not found.\n")



inventory = []

while True:
  print("Inventory Management System")
  print("1. Add a New Product")
  print("2. View Inventory")
  print("3. Update Product Quantity")
  print("4. Remove a Product")
  print("5. Exit Program")

  choice = input("Enter your choice (1-5): ").strip()

  if choice == '1':
    add_product(inventory)
  elif choice == '2':
    view_inventory(inventory)
  elif choice == '3':
    update_product_quantity(inventory)
  elif choice == '4':
    remove_product(inventory)
  elif choice == '5':
    print("Exiting the program. Goodbye!")
    break
  else:
    print("Invalid choice. Please try again.\n")
# Out:
# Inventory Management System
# 1. Add a New Product
# 2. View Inventory
# 3. Update Product Quantity
# 4. Remove a Product
# 5. Exit Program
# Enter your choice (1-5): 1
# Enter product name: Cap
# Enter product ID: 1
# Enter product quantity: 12
# Enter product price: 500
# Product Cap added successfully.
#
# Inventory Management System
# 1. Add a New Product
# 2. View Inventory
# 3. Update Product Quantity
# 4. Remove a Product
# 5. Exit Program
# Enter your choice (1-5): 2
# Current Inventory:
# Name: Cap, ID: 1, Quantity: 12, Price: 500.00
#
# Inventory Management System
# 1. Add a New Product
# 2. View Inventory
# 3. Update Product Quantity
# 4. Remove a Product
# 5. Exit Program
# Enter your choice (1-5): 3
# Enter the product ID to update: 1
# Enter the new quantity: 15
# Quantity of product Cap updated successfully.
#
# Inventory Management System
# 1. Add a New Product
# 2. View Inventory
# 3. Update Product Quantity
# 4. Remove a Product
# 5. Exit Program
# Enter your choice (1-5): 5
# Exiting the program. Goodbye!
